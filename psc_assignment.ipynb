# %% [markdown]
# # DAV Assignment

# %% [markdown]
# ### Data cleaning

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("heart_2022_with_nans.csv")

# %%
df.head(10)
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 0.0               0.0
# 1  Alabama  Female     Excellent                 0.0               0.0
# 2  Alabama  Female     Very good                 2.0               3.0
# 3  Alabama  Female     Excellent                 0.0               0.0
# 4  Alabama  Female          Fair                 2.0               0.0
# 5  Alabama    Male          Poor                 1.0               0.0
# 6  Alabama  Female     Very good                 0.0               0.0
# 7  Alabama  Female          Good                 0.0               0.0
# 8  Alabama  Female          Good                 0.0               0.0
# 9  Alabama  Female          Good                 1.0               0.0
#
#                                      LastCheckupTime PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                 No
# ...

# %% [markdown]
# Checking for null

# %%
df.isnull().sum()
# Out:
# State                            0
# Sex                              0
# GeneralHealth                 1198
# PhysicalHealthDays           10927
# MentalHealthDays              9067
# LastCheckupTime               8308
# PhysicalActivities            1093
# SleepHours                    5453
# RemovedTeeth                 11360
# HadHeartAttack                3065
# HadAngina                     4405
# HadStroke                     1557
# HadAsthma                     1773
# HadSkinCancer                 3143
# HadCOPD                       2219
# HadDepressiveDisorder         2812
# HadKidneyDisease              1926
# HadArthritis                  2633
# HadDiabetes                   1087
# DeafOrHardOfHearing          20647
# BlindOrVisionDifficulty      21564
# DifficultyConcentrating      24240
# DifficultyWalking            24012
# DifficultyDressingBathing    23915
# DifficultyErrands            25656
# SmokerStatus                 35462
# ECigaretteUsage              35660
# ...

# %% [markdown]
# Removing Nulls

# %%
print("Initial shape of dataset - ", df.shape,'\n')
df = df.dropna().reset_index(drop=True)
print("New shape after removing NaN's - ",df.shape,'\n')
df.isnull().sum()
# Out:
# Initial shape of dataset -  (445132, 40)
#
# New shape after removing NaN's -  (246022, 40)
# State                        0
# Sex                          0
# GeneralHealth                0
# PhysicalHealthDays           0
# MentalHealthDays             0
# LastCheckupTime              0
# PhysicalActivities           0
# SleepHours                   0
# RemovedTeeth                 0
# HadHeartAttack               0
# HadAngina                    0
# HadStroke                    0
# HadAsthma                    0
# HadSkinCancer                0
# HadCOPD                      0
# HadDepressiveDisorder        0
# HadKidneyDisease             0
# HadArthritis                 0
# HadDiabetes                  0
# DeafOrHardOfHearing          0
# BlindOrVisionDifficulty      0
# DifficultyConcentrating      0
# DifficultyWalking            0
# DifficultyDressingBathing    0
# DifficultyErrands            0
# SmokerStatus                 0
# ECigaretteUsage              0
# ...

# %% [markdown]
# checking for duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(9)

# %% [markdown]
# Removing duplicates

# %%
print('Shape before removing duplicates ', df.shape,'\n')
df.drop_duplicates(inplace=True)
print('Shape after removing duplicates ', df.shape,'\n')
# Out:
# Shape before removing duplicates  (246022, 40)
#
# Shape after removing duplicates  (246013, 40)

# %% [markdown]
# ### Exploring dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 246013 entries, 0 to 246021
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   State                      246013 non-null  object
#  1   Sex                        246013 non-null  object
#  2   GeneralHealth              246013 non-null  object
#  3   PhysicalHealthDays         246013 non-null  float64
#  4   MentalHealthDays           246013 non-null  float64
#  5   LastCheckupTime            246013 non-null  object
#  6   PhysicalActivities         246013 non-null  object
#  7   SleepHours                 246013 non-null  float64
#  8   RemovedTeeth               246013 non-null  object
#  9   HadHeartAttack             246013 non-null  object
#  10  HadAngina                  246013 non-null  object
#  11  HadStroke                  246013 non-null  object
#  12  HadAsthma                  246013 non-null  object
# ...

# %% [markdown]
# #### Tranforming large strings into short ones for easy visualization
#
# 1. LastCheckupTime

# %%
print(df['LastCheckupTime'].head(5))
a = df['LastCheckupTime'].unique()
new_checkup_time = ['Recently','1Year','2Year','>2Year']
df['LastCheckupTime'] = df['LastCheckupTime'].replace(a,new_checkup_time)
df['LastCheckupTime'].head(5)
# Out:
# 0    Within past year (anytime less than 12 months ...
# 1    Within past year (anytime less than 12 months ...
# 2    Within past year (anytime less than 12 months ...
# 3    Within past year (anytime less than 12 months ...
# 4    Within past year (anytime less than 12 months ...
# Name: LastCheckupTime, dtype: object
# 0    Recently
# 1    Recently
# 2    Recently
# 3    Recently
# 4    Recently
# Name: LastCheckupTime, dtype: object

# %% [markdown]
# 2. SmokerStatus

# %%
print(df['SmokerStatus'].head(5))
a = df['SmokerStatus'].unique()
new_smoker_status = ['Never','Somedays','Former','Everyday']
df['SmokerStatus'] = df['SmokerStatus'].replace(a,new_smoker_status)
df['SmokerStatus'].head(5)
# Out:
# 0    Former smoker
# 1    Former smoker
# 2    Former smoker
# 3     Never smoked
# 4     Never smoked
# Name: SmokerStatus, dtype: object
# 0       Never
# 1       Never
# 2       Never
# 3    Somedays
# 4    Somedays
# Name: SmokerStatus, dtype: object

# %% [markdown]
# 3. ECigaretteUsage

# %%
print(df['ECigaretteUsage'].head(5))
a = df['ECigaretteUsage'].unique()
new_Esmoker_status = ['Never','Somedays','Former','Everyday']
df['ECigaretteUsage'] = df['ECigaretteUsage'].replace(a,new_smoker_status)
df['ECigaretteUsage'].head(5)
# Out:
# 0    Never used e-cigarettes in my entire life
# 1    Never used e-cigarettes in my entire life
# 2    Never used e-cigarettes in my entire life
# 3    Never used e-cigarettes in my entire life
# 4    Never used e-cigarettes in my entire life
# Name: ECigaretteUsage, dtype: object
# 0    Never
# 1    Never
# 2    Never
# 3    Never
# 4    Never
# Name: ECigaretteUsage, dtype: object

# %% [markdown]
# 4. RaceEthnicityCategory

# %%
print(df['RaceEthnicityCategory'].head(5))
a = df['RaceEthnicityCategory'].unique()
new_Race = ['White','Black','Other','Multiracial','Hispanic']
df['RaceEthnicityCategory'] = df['RaceEthnicityCategory'].replace(a,new_Race)
df['RaceEthnicityCategory'].head(5)
# Out:
# 0    White only, Non-Hispanic
# 1    White only, Non-Hispanic
# 2    White only, Non-Hispanic
# 3    White only, Non-Hispanic
# 4    White only, Non-Hispanic
# Name: RaceEthnicityCategory, dtype: object
# 0    White
# 1    White
# 2    White
# 3    White
# 4    White
# Name: RaceEthnicityCategory, dtype: object

# %% [markdown]
# 5. AgeCategory

# %%
print(df['AgeCategory'].head(5))
a = df['AgeCategory'].unique()
new_Age = ['Old','Old','Old','Old','Adult','Adult','Adult','Adult','Adult','Adult','Young','Adult','Young']
df['AgeCategory'] = df['AgeCategory'].replace(a,new_Age)
df['AgeCategory'].head(5)
# Out:
# 0       Age 65 to 69
# 1       Age 70 to 74
# 2       Age 75 to 79
# 3    Age 80 or older
# 4    Age 80 or older
# Name: AgeCategory, dtype: object
# 0    Old
# 1    Old
# 2    Old
# 3    Old
# 4    Old
# Name: AgeCategory, dtype: object

# %% [markdown]
# 6. TetanusLast10Tdap

# %%
print(df['TetanusLast10Tdap'].head(5))
a = df['TetanusLast10Tdap'].unique()
new_Tetanus = ['Yes','Yes','No','No']
df['TetanusLast10Tdap'] = df['TetanusLast10Tdap'].replace(a,new_Tetanus)
df['TetanusLast10Tdap'].head(5)
# Out:
# 0                                   Yes, received Tdap
# 1    Yes, received tetanus shot but not sure what type
# 2    No, did not receive any tetanus shot in the pa...
# 3    No, did not receive any tetanus shot in the pa...
# 4    No, did not receive any tetanus shot in the pa...
# Name: TetanusLast10Tdap, dtype: object
# 0    Yes
# 1    Yes
# 2     No
# 3     No
# 4     No
# Name: TetanusLast10Tdap, dtype: object

# %% [markdown]
# 7. RemovedTeeth

# %%
print(df['RemovedTeeth'].head(5))
a = df['RemovedTeeth'].unique()
new_Teeth = ['None','6orMore','1To5','All']
df['RemovedTeeth'] = df['RemovedTeeth'].replace(a,new_Teeth)
df['RemovedTeeth'].head(5)
# Out:
# 0              None of them
# 1              None of them
# 2    6 or more, but not all
# 3              None of them
# 4                    1 to 5
# Name: RemovedTeeth, dtype: object
# 0       None
# 1       None
# 2    6orMore
# 3       None
# 4       1To5
# Name: RemovedTeeth, dtype: object

# %% [markdown]
# 8. HadDiabetes

# %%
print(df['HadDiabetes'].head(5))
a = df['HadDiabetes'].unique()
a
new_Teeth = ['No','Yes','Yes','No']
df['HadDiabetes'] = df['HadDiabetes'].replace(a,new_Teeth)
df['HadDiabetes'].head(5)
# Out:
# 0     No
# 1    Yes
# 2     No
# 3     No
# 4     No
# Name: HadDiabetes, dtype: object
# 0     No
# 1    Yes
# 2     No
# 3     No
# 4     No
# Name: HadDiabetes, dtype: object

# %%
df.to_csv("heart_2022_cleaned.csv")

# %% [markdown]
# #### Visualizing dataset

# %%
color1 = ['#BB5C5C', '#249EA3']
color2 = ['#79A468','#CFB95C']
color3 = ['#BB5C5C', '#249EA3','#79A468','#CFB95C']

# %% [markdown]
# BasedOnGender

# %%
plt.bar(df['Sex'].unique(),df['Sex'].value_counts(),color = color1)
# Out:
# <BarContainer object of 2 artists>

# %%
a = df['Sex'][df['HadHeartAttack'] == 'Yes'].value_counts()
b = df['Sex'][df['HadHeartAttack'] == 'No'].value_counts()
X = np.arange(len(df['Sex'].unique()))
bar1 = plt.bar(X - 0.2,a,0.4,color = color1[0],label = 'Yes')
bar2 = plt.bar(X + 0.2,b,0.4,color = color1[1],label= 'No')
plt.xticks(X,df['Sex'].unique())
plt.xlabel("Sex")
plt.ylabel("HadHeartAttack")
plt.bar_label(bar1)
plt.bar_label(bar2)
plt.legend()
plt.show()

# %% [markdown]
# Based on Age

# %%
plt.bar(df['AgeCategory'].unique(), df['AgeCategory'].value_counts(),color = color1)
# Out:
# <BarContainer object of 3 artists>

# %%
a = df['AgeCategory'][df['HadHeartAttack'] == 'Yes'].value_counts()
b = df['AgeCategory'][df['HadHeartAttack'] == 'No'].value_counts()
X = np.arange(len(df['AgeCategory'].unique()))
bar1 = plt.bar(X - 0.2,a,0.4,color = color1[0],label = 'Yes')
bar2 = plt.bar(X + 0.2,b,0.4,color = color1[1],label= 'No')
plt.xticks(X,df['AgeCategory'].unique())
plt.xlabel("AgeCategory")
plt.ylabel("HadHeartAttack")
plt.bar_label(bar1)
plt.bar_label(bar2)
plt.legend()
plt.show()

# %% [markdown]
# BasedOnHealthAndDiasease

# %%
plt.bar(df['GeneralHealth'].unique(), df['GeneralHealth'].value_counts(),color = color3)
# Out:
# <BarContainer object of 5 artists>

# %%
a = df['GeneralHealth'][df['HadHeartAttack'] == 'Yes'].value_counts()
b = df['GeneralHealth'][df['HadHeartAttack'] == 'No'].value_counts()
X = np.arange(len(df['GeneralHealth'].unique()))
bar1 = plt.bar(X - 0.2,a,0.4,label = 'Yes',color = color1[0])
bar2 = plt.bar(X + 0.2,b,0.4,label= 'No',color = color1[1])
plt.xticks(X,df['GeneralHealth'].unique())
plt.xlabel("GeneralHealth")
plt.ylabel("HadHeartAttack")
plt.bar_label(bar1)
plt.bar_label(bar2)
plt.legend()
plt.show()

# %%
c = a/(a+b)   # Ratio of HadHeartAttack / Total
plt.bar(df['GeneralHealth'].unique(), c, color = color3)
plt.title('Ratio of heart Attack based on general health')
# Out:
# Text(0.5, 1.0, 'Ratio of heart Attack based on general health')

# %%
plt.bar(df['PhysicalHealthDays'].unique(),df['PhysicalHealthDays'].value_counts())
# Out:
# <BarContainer object of 31 artists>

# %%
def remove_ouliers(data):
    for column in data.columns:
        if column in ['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime']:
            Q1 = data[column].quantile(0.25)
            Q3 = data[column].quantile(0.75)
            IQR = Q3 - Q1
        
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR
        
            data = data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]
    return data

# %%
df = remove_ouliers(df)
plt.boxplot(df['PhysicalHealthDays'],patch_artist=True)
plt.show()

# %%
a = df['PhysicalHealthDays'][df['HadHeartAttack'] == 'Yes']
b = df['PhysicalHealthDays'][df['HadHeartAttack'] == 'No']
fig,ax = plt.subplots()
ax.boxplot([a,b],patch_artist=True)
plt.xticks([1,2],['Yes','No'])
ax.set_xlabel('HadHeartAttack')
ax.set_ylabel('PhysicalHealthDays')
plt.show()

# %%
plt.boxplot(df['MentalHealthDays'],patch_artist=True)
plt.show()

# %%
a = df['MentalHealthDays'][df['HadHeartAttack'] == 'Yes']
b = df['MentalHealthDays'][df['HadHeartAttack'] == 'No']
fig,ax = plt.subplots()
ax.boxplot([a,b],patch_artist=True)
plt.xticks([1,2],['Yes','No'])
ax.set_xlabel('HadHeartAttack')
ax.set_ylabel('MentalHealthDays')
plt.show()

# %%
bar1 = plt.bar(df['PhysicalActivities'].unique(),df['PhysicalActivities'].value_counts(),color = color1)
plt.xlabel("PhysicalActivities")
plt.ylabel("Count")
plt.bar_label(bar1)
plt.show()

# %%
a = df['PhysicalActivities'][df['HadHeartAttack'] == 'Yes'].value_counts()
b = df['PhysicalActivities'][df['HadHeartAttack'] == 'No'].value_counts()
X = np.arange(len(df['PhysicalActivities'].unique()))
bar1 = plt.bar(X - 0.2,a,0.4,label = 'Yes',color = color1[0])
bar2 = plt.bar(X + 0.2,b,0.4,label= 'No',color = color1[1])
plt.xticks(X,df['PhysicalActivities'].unique())
plt.xlabel("PhysicalActivities")
plt.ylabel("HadHeartAttack")
plt.bar_label(bar1)
plt.bar_label(bar2)
plt.legend()
plt.show()

# %%
c = [a.iloc[0]/((a.iloc[0]+b.iloc[0])), a.iloc[1]/((a.iloc[1]+b.iloc[1]))]
d = [b.iloc[0]/((a.iloc[0]+b.iloc[0])), b.iloc[1]/((a.iloc[1]+b.iloc[1]))]
bar1 = plt.bar(X-0.2,c,0.4,label = 'Yes',color = color1[0])
bar2 = plt.bar(X + 0.2,d,0.4,label= 'No',color = color1[1])
plt.xticks(X,df['PhysicalActivities'].unique())
plt.xlabel("PhysicalActivities")
plt.ylabel("HadHeartAttack")
plt.bar_label(bar1)
plt.bar_label(bar2)
plt.title('Ratio of people having heart attack based on physical activities')
plt.legend()
plt.show()

# %%
plt.bar(df['SleepHours'].unique(),df['SleepHours'].value_counts())
plt.show()

# %%
a = df['SleepHours'][df['HadHeartAttack'] == 'Yes']
b = df['SleepHours'][df['HadHeartAttack'] == 'No']
fig,ax = plt.subplots()
ax.boxplot([a,b],patch_artist=True)
plt.xticks([1,2],['Yes','No'])
ax.set_xlabel('HadHeartAttack')
ax.set_ylabel('SleepHours')
plt.show()

# %%
bar1 = plt.bar(df['RemovedTeeth'].unique(),df['RemovedTeeth'].value_counts(),0.5,color = color1)
plt.xlabel("RemovedTeeth")
plt.ylabel("Count")
plt.bar_label(bar1)
plt.show()

# %%
a = df['RemovedTeeth'][df['HadHeartAttack'] == 'Yes'].value_counts()
b = df['RemovedTeeth'][df['HadHeartAttack'] == 'No'].value_counts()
X = np.arange(len(df['RemovedTeeth'].unique()))
bar1 = plt.bar(X - 0.2,a,0.4,label = 'Yes',color = color1[0])
bar2 = plt.bar(X + 0.2,b,0.4,label= 'No',color = color1[1])
plt.xticks(X,df['RemovedTeeth'].unique())
plt.xlabel("RemovedTeeth")
plt.ylabel("HadHeartAttack")
plt.bar_label(bar1)
plt.bar_label(bar2)
plt.legend()
plt.show()

# %%
fig,ax = plt.subplots(2,2,figsize = (8,8))
fig.tight_layout()
plt.subplots_adjust(wspace=0.3)
b1 = ax[0,0].bar(df['HadAngina'].unique(),df['HadAngina'].value_counts(),0.5,color = color1)
ax[0,0].set_title("HadAngina")
ax[0,0].set_ylabel("Count")
ax[0,0].bar_label(b1)

b1 = ax[0,1].bar(df['HadStroke'].unique(),df['HadStroke'].value_counts(),0.5,color = color1)
ax[0,1].set_title("HadStroke")
ax[0,1].set_ylabel("Count")
ax[0,1].bar_label(b1)

b1 = ax[1,0].bar(df['HadAsthma'].unique(),df['HadAsthma'].value_counts(),0.5,color = color1)
ax[1,0].set_title("HadAsthma")
ax[1,0].set_ylabel("Count")
ax[1,0].bar_label(b1)

b1 = ax[1,1].bar(df['HadSkinCancer'].unique(),df['HadSkinCancer'].value_counts(),0.5,color = color1)
ax[1,1].set_title("HadSkinCancer")
ax[1,1].set_ylabel("Count")
ax[1,1].bar_label(b1)
plt.show()

# %%
fig,ax = plt.subplots(3,3,figsize = (10,10))
fig.tight_layout()
plt.subplots_adjust(hspace=0.2,wspace=0.4)

a = df['HadAngina'][df['HadHeartAttack'] == 'Yes'].value_counts()
b = df['HadAngina'][df['HadHeartAttack'] == 'No'].value_counts()
X = np.arange(len(df['HadAngina'].unique()))
bar1 = ax[0,0].bar(X,b,0.4,label= 'No',color = color1[1])
bar2 = ax[0,0].bar(X,a,0.4,label = 'Yes',color = color1[0])
ax[0,0].set_xticks(X,df['HadAngina'].unique())
ax[0,0].set_title("HadAngina")
ax[0,0].set_ylabel("HadHeartAttack")
# ax[0,0].bar_label(bar1)
# ax[0,0].bar_label(bar2)
ax[0,0].legend()

a = df['HadStroke'][df['HadHeartAttack'] == 'Yes'].value_counts()
b = df['HadStroke'][df['HadHeartAttack'] == 'No'].value_counts()
X = np.arange(len(df['HadStroke'].unique()))
bar1 = ax[0,1].bar(X,b,0.4,label= 'No',color = color1[1])
bar2 = ax[0,1].bar(X,a,0.4,label = 'Yes',color = color1[0])
ax[0,1].set_xticks(X,df['HadStroke'].unique())
ax[0,1].set_title("HadStroke")
ax[0,1].set_ylabel("HadHeartAttack")
# ax[0,1].bar_label(bar1)
# ax[0,1].bar_label(bar2)
ax[0,1].legend()

a = df['HadAsthma'][df['HadHeartAttack'] == 'Yes'].value_counts()
b = df['HadAsthma'][df['HadHeartAttack'] == 'No'].value_counts()
X = np.arange(len(df['HadAsthma'].unique()))
bar1 = ax[0,2].bar(X,b,0.4,label= 'No',color = color1[1])
bar2 = ax[0,2].bar(X,a,0.4,label = 'Yes',color = color1[0])
ax[0,2].set_xticks(X,df['HadAsthma'].unique())
ax[0,2].set_title("HadAsthma")
ax[0,2].set_ylabel("HadHeartAttack")
# ax[0,2].bar_label(bar1)
# ax[0,2].bar_label(bar2)
ax[0,2].legend()

a = df['HadSkinCancer'][df['HadHeartAttack'] == 'Yes'].value_counts()
b = df['HadSkinCancer'][df['HadHeartAttack'] == 'No'].value_counts()
X = np.arange(len(df['HadSkinCancer'].unique()))
bar1 = ax[1,0].bar(X,b,0.4,label= 'No',color = color1[1])
bar2 = ax[1,0].bar(X,a,0.4,label = 'Yes',color = color1[0])
ax[1,0].set_xticks(X,df['HadSkinCancer'].unique())
ax[1,0].set_title("HadSkinCancer")
ax[1,0].set_ylabel("HadHeartAttack")
# ax[1,0].bar_label(bar1)
# ax[1,0].bar_label(bar2)
ax[1,0].legend()

a = df['HadCOPD'][df['HadHeartAttack'] == 'Yes'].value_counts()
b = df['HadCOPD'][df['HadHeartAttack'] == 'No'].value_counts()
X = np.arange(len(df['HadCOPD'].unique()))
bar1 = ax[1,1].bar(X,b,0.4,label= 'No',color = color1[1])
bar2 = ax[1,1].bar(X,a,0.4,label = 'Yes',color = color1[0])
ax[1,1].set_xticks(X,df['HadCOPD'].unique())
ax[1,1].set_title("HadCOPD")
ax[1,1].set_ylabel("HadHeartAttack")
# ax[1,1].bar_label(bar1)
# ax[1,1].bar_label(bar2)
ax[1,1].legend()

a = df['HadDepressiveDisorder'][df['HadHeartAttack'] == 'Yes'].value_counts()
b = df['HadDepressiveDisorder'][df['HadHeartAttack'] == 'No'].value_counts()
X = np.arange(len(df['HadDepressiveDisorder'].unique()))
bar1 = ax[1,2].bar(X,b,0.4,label= 'No',color = color1[1])
bar2 = ax[1,2].bar(X,a,0.4,label = 'Yes',color = color1[0])
ax[1,2].set_xticks(X,df['HadDepressiveDisorder'].unique())
ax[1,2].set_title("HadDepressiveDisorder")
ax[1,2].set_ylabel("HadHeartAttack")
# ax[1,2].bar_label(bar1)
# ax[1,2].bar_label(bar2)
ax[1,2].legend()

a = df['HadKidneyDisease'][df['HadHeartAttack'] == 'Yes'].value_counts()
b = df['HadKidneyDisease'][df['HadHeartAttack'] == 'No'].value_counts()
X = np.arange(len(df['HadKidneyDisease'].unique()))
bar1 = ax[2,0].bar(X,b,0.4,label= 'No',color = color1[1])
bar2 = ax[2,0].bar(X,a,0.4,label = 'Yes',color = color1[0])
ax[2,0].set_xticks(X,df['HadKidneyDisease'].unique())
ax[2,0].set_title("HadKidneyDisease")
ax[2,0].set_ylabel("HadHeartAttack")
# ax[2,0].bar_label(bar1)
# ax[2,0].bar_label(bar2)
ax[2,0].legend()

a = df['HadArthritis'][df['HadHeartAttack'] == 'Yes'].value_counts()
b = df['HadArthritis'][df['HadHeartAttack'] == 'No'].value_counts()
X = np.arange(len(df['HadArthritis'].unique()))
bar1 = ax[2,1].bar(X,b,0.4,label= 'No',color = color1[1])
bar2 = ax[2,1].bar(X,a,0.4,label = 'Yes',color = color1[0])
ax[2,1].set_xticks(X,df['HadArthritis'].unique())
ax[2,1].set_title("HadArthritis")
ax[2,1].set_ylabel("HadHeartAttack")
# ax[2,1].bar_label(bar1)
# ax[2,1].bar_label(bar2)
ax[2,1].legend()

a = df['HadDiabetes'][df['HadHeartAttack'] == 'Yes'].value_counts()
b = df['HadDiabetes'][df['HadHeartAttack'] == 'No'].value_counts()
X = np.arange(len(df['HadDiabetes'].unique()))
bar1 = ax[2,2].bar(X,b,0.4,label= 'No',color = color1[1])
bar2 = ax[2,2].bar(X,a,0.4,label = 'Yes',color = color1[0])
ax[2,2].set_xticks(X,df['HadDiabetes'].unique())
ax[2,2].set_title("HadDiabetes")
ax[2,2].set_ylabel("HadHeartAttack")
# ax[2,1].bar_label(bar1)
# ax[2,1].bar_label(bar2)
ax[2,2].legend()
plt.show()

# %% [markdown]
# Disability

# %%
fig,ax = plt.subplots(2,3,figsize = (10,10))
fig.tight_layout()
plt.subplots_adjust(hspace=0.2,wspace=0.4)

a = df['DeafOrHardOfHearing'][df['HadHeartAttack'] == 'Yes'].value_counts()
b = df['DeafOrHardOfHearing'][df['HadHeartAttack'] == 'No'].value_counts()
X = np.arange(len(df['DeafOrHardOfHearing'].unique()))
bar1 = ax[0,0].bar(X,b,0.4,label= 'No',color = color1[1])
bar2 = ax[0,0].bar(X,a,0.4,label = 'Yes',color = color1[0])
ax[0,0].set_xticks(X,df['DeafOrHardOfHearing'].unique())
ax[0,0].set_title("DeafOrHardOfHearing")
ax[0,0].set_ylabel("HadHeartAttack")
# ax[0,0].bar_label(bar1)
# ax[0,0].bar_label(bar2)
ax[0,0].legend()

a = df['BlindOrVisionDifficulty'][df['HadHeartAttack'] == 'Yes'].value_counts()
b = df['BlindOrVisionDifficulty'][df['HadHeartAttack'] == 'No'].value_counts()
X = np.arange(len(df['BlindOrVisionDifficulty'].unique()))
bar1 = ax[0,1].bar(X,b,0.4,label= 'No',color = color1[1])
bar2 = ax[0,1].bar(X,a,0.4,label = 'Yes',color = color1[0])
ax[0,1].set_xticks(X,df['BlindOrVisionDifficulty'].unique())
ax[0,1].set_title("BlindOrVisionDifficulty")
ax[0,1].set_ylabel("HadHeartAttack")
# ax[0,1].bar_label(bar1)
# ax[0,1].bar_label(bar2)
ax[0,1].legend()

a = df['DifficultyConcentrating'][df['HadHeartAttack'] == 'Yes'].value_counts()
b = df['DifficultyConcentrating'][df['HadHeartAttack'] == 'No'].value_counts()
X = np.arange(len(df['DifficultyConcentrating'].unique()))
bar1 = ax[0,2].bar(X,b,0.4,label= 'No',color = color1[1])
bar2 = ax[0,2].bar(X,a,0.4,label = 'Yes',color = color1[0])
ax[0,2].set_xticks(X,df['DifficultyConcentrating'].unique())
ax[0,2].set_title("DifficultyConcentrating")
ax[0,2].set_ylabel("HadHeartAttack")
# ax[0,2].bar_label(bar1)
# ax[0,2].bar_label(bar2)
ax[0,2].legend()

a = df['DifficultyWalking'][df['HadHeartAttack'] == 'Yes'].value_counts()
b = df['DifficultyWalking'][df['HadHeartAttack'] == 'No'].value_counts()
X = np.arange(len(df['DifficultyWalking'].unique()))
bar1 = ax[1,0].bar(X,b,0.4,label= 'No',color = color1[1])
bar2 = ax[1,0].bar(X,a,0.4,label = 'Yes',color = color1[0])
ax[1,0].set_xticks(X,df['DifficultyWalking'].unique())
ax[1,0].set_title("DifficultyWalking")
ax[1,0].set_ylabel("HadHeartAttack")
# ax[1,0].bar_label(bar1)
# ax[1,0].bar_label(bar2)
ax[1,0].legend()

a = df['DifficultyDressingBathing'][df['HadHeartAttack'] == 'Yes'].value_counts()
b = df['DifficultyDressingBathing'][df['HadHeartAttack'] == 'No'].value_counts()
X = np.arange(len(df['DifficultyDressingBathing'].unique()))
bar1 = ax[1,1].bar(X,b,0.4,label= 'No',color = color1[1])
bar2 = ax[1,1].bar(X,a,0.4,label = 'Yes',color = color1[0])
ax[1,1].set_xticks(X,df['DifficultyDressingBathing'].unique())
ax[1,1].set_title("DifficultyDressingBathing")
ax[1,1].set_ylabel("HadHeartAttack")
# ax[1,1].bar_label(bar1)
# ax[1,1].bar_label(bar2)
ax[1,1].legend()

a = df['DifficultyErrands'][df['HadHeartAttack'] == 'Yes'].value_counts()
b = df['DifficultyErrands'][df['HadHeartAttack'] == 'No'].value_counts()
X = np.arange(len(df['DifficultyErrands'].unique()))
bar1 = ax[1,2].bar(X,b,0.4,label= 'No',color = color1[1])
bar2 = ax[1,2].bar(X,a,0.4,label = 'Yes',color = color1[0])
ax[1,2].set_xticks(X,df['DifficultyErrands'].unique())
ax[1,2].set_title("DifficultyErrands")
ax[1,2].set_ylabel("HadHeartAttack")
# ax[1,2].bar_label(bar1)
# ax[1,2].bar_label(bar2)
ax[1,2].legend()

# %%
data = df.corr(numeric_only=True)
data
# Out:
#                     PhysicalHealthDays  MentalHealthDays  SleepHours  \
# PhysicalHealthDays            1.000000          0.301178   -0.055956
# MentalHealthDays              0.301178          1.000000   -0.129658
# SleepHours                   -0.055956         -0.129658    1.000000
# HeightInMeters               -0.046932         -0.054300   -0.011733
# WeightInKilograms             0.040578          0.007260   -0.047513
# BMI                           0.080720          0.046848   -0.048690
#
#                     HeightInMeters  WeightInKilograms       BMI
# PhysicalHealthDays       -0.046932           0.040578  0.080720
# MentalHealthDays         -0.054300           0.007260  0.046848
# SleepHours               -0.011733          -0.047513 -0.048690
# HeightInMeters            1.000000           0.550721  0.012306
# WeightInKilograms         0.550721           1.000000  0.834453
# BMI                       0.012306           0.834453  1.000000

# %%
fig, ax = plt.subplots()
im = plt.imshow(data)
ax.set_yticks(np.arange(len(data.columns)), labels=data.columns)
ax.set_xticks(np.arange(len(data.columns)), labels=data.columns)
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",rotation_mode="anchor")
plt.show()

# %%
df = df.replace(['Yes','No'],[1,0])
df.to_csv("heart_2022_numeric.csv")
# Out:
# C:\Users\rajat\AppData\Local\Temp\ipykernel_69980\684581951.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(['Yes','No'],[1,0])

# %%
data = df.corr(numeric_only=True)
data.loc['HadHeartAttack']
# Out:
# PhysicalHealthDays           0.133243
# MentalHealthDays             0.025025
# PhysicalActivities          -0.084006
# SleepHours                   0.003070
# HadHeartAttack               1.000000
# HadAngina                    0.448658
# HadStroke                    0.176784
# HadAsthma                    0.022601
# HadSkinCancer                0.049808
# HadCOPD                      0.132877
# HadDepressiveDisorder        0.023022
# HadKidneyDisease             0.109047
# HadArthritis                 0.117619
# HadDiabetes                  0.140597
# DeafOrHardOfHearing          0.097058
# BlindOrVisionDifficulty      0.072206
# DifficultyConcentrating      0.051498
# DifficultyWalking            0.160096
# DifficultyDressingBathing    0.080660
# DifficultyErrands            0.088926
# ChestScan                    0.168330
# HeightInMeters               0.024489
# WeightInKilograms            0.040956
# BMI                          0.032597
# AlcoholDrinkers             -0.074133
# ...

# %%
fig, ax = plt.subplots(figsize = (10,10))
im = plt.imshow(data)
ax.set_yticks(np.arange(len(data.columns)), labels=data.columns)
ax.set_xticks(np.arange(len(data.columns)), labels=data.columns)
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",rotation_mode="anchor")
plt.show()
